# %%
import pandas as pd

data=pd.read_csv("healthcare_cardiovascular_risk_dataset.csv")

# %%
data=data.drop("Patient_ID",axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Encode target
data["Cardiovascular_Risk"] = le.fit_transform(data["Cardiovascular_Risk"])

# Verify
print(data["Cardiovascular_Risk"].head())
print(data["Cardiovascular_Risk"].dtype)

# Encode remaining object columns
obj_cols = data.select_dtypes(include="object").columns

data = pd.get_dummies(data, columns=obj_cols, dtype=int)
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Cardiovascular_Risk, dtype: int32
# int32

# %%
data
# Out:
#      Age   BMI  Cholesterol  Systolic_BP  Heart_Rate  Sleep_Hours  \
# 0     69  28.5        241.0          140          63          5.9
# 1     32  26.2        178.0          123          68          6.9
# 2     78  28.4        176.0          138          67          7.7
# 3     38  31.4        212.0          141          76          7.9
# 4     41  31.9        253.0          109          86          7.2
# ..   ...   ...          ...          ...         ...          ...
# 745   23  20.3        214.0          131          60          8.5
# 746   67  25.6        261.0          145          89          6.6
# 747   27  28.7        198.0          121          76          4.9
# 748   22  26.1        231.0          120          75          5.5
# 749   40  27.1        199.0          123          83          7.0
#
#      Healthcare_Visits_Last_Year  Cardiovascular_Risk  Gender_Female  \
# 0                              4                    1              1
# ...

# %%
data.isnull().sum()
# Out:
# Age                                    0
# BMI                                   22
# Cholesterol                           22
# Systolic_BP                            0
# Heart_Rate                             0
# Sleep_Hours                           22
# Healthcare_Visits_Last_Year            0
# Cardiovascular_Risk                    0
# Gender_Female                          0
# Gender_Male                            0
# Gender_Other                           0
# Smoking_Status_Current                 0
# Smoking_Status_Former                  0
# Smoking_Status_Never                   0
# Diabetes_No                            0
# Diabetes_Yes                           0
# Hypertension_No                        0
# Hypertension_Yes                       0
# Physical_Activity_High                 0
# Physical_Activity_Low                  0
# Physical_Activity_Moderate             0
# Family_History_Cardiac_Disease_No      0
# Family_History_Cardiac_Disease_Yes     0
# ...

# %%
x=data.drop("Cardiovascular_Risk",axis=1)

# %%
y=data["Cardiovascular_Risk"]

# %%
from sklearn.model_selection import train_test_split
model=LogisticRegression()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 from sklearn.model_selection import LogisticRegression
#       2 model=LogisticRegression()
#
# ImportError: cannot import name 'LogisticRegression' from 'sklearn.model_selection' (c:\Users\sahib\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\__init__.py)
